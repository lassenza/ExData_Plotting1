# %% [markdown]
# <a href="https://colab.research.google.com/github/lassenza/ExData_Plotting1/blob/master/Document_Text_Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai pandas python-dotenv

# %%
import os
import json
import pandas as pd
import openai
from google.colab import userdata

# %%
# Securely load your API key
openai.api_key = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

response = client.completions.create(
  model="gpt-3.5-turbo-instruct",
  prompt=" How likely is AC Fiorentina to win the Conference League this year? ",
  max_tokens=100,
  temperature=0.8
)
print(response.choices[0].text.strip())
# Out:
# It is difficult to predict the outcome of a tournament, especially since the Conference League is a new competition. However, AC Fiorentina is a strong team with a solid history in European competitions, so they could be considered contenders for the title. It will ultimately depend on their performance throughout the tournament and the strength of their opponents.
